# %%
# !pip install hvplot geoviews datashader geopandas
# Out:
# Requirement already satisfied: hvplot in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (0.8.4)
# Requirement already satisfied: geoviews in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (1.10.1)
# Requirement already satisfied: datashader in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (0.15.1)
# Collecting geopandas
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/27/27/2687abaa2ac02b5814e2929a5033da1e5d132c19a904dc56f77f63fd6eb9/geopandas-0.14.0-py3-none-any.whl.metadata
#   Downloading geopandas-0.14.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: bokeh>=1.0.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (3.2.1)
# Requirement already satisfied: colorcet>=2 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (1.17.0)
# Requirement already satisfied: pandas in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (1.5.3)
# Requirement already satisfied: numpy>=1.15 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (1.24.3)
# Requirement already satisfied: packaging in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (23.0)
# Requirement already satisfied: panel>=0.11.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (1.2.1)
# Requirement already satisfied: param>=1.9.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from hvplot) (1.13.0)
# Requirement already satisfied: cartopy>=0.18.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: shapely in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: pyproj in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: dask in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (2023.6.0)
# Requirement already satisfied: datashape in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (0.5.4)
# Requirement already satisfied: numba in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (0.57.0)
# Requirement already satisfied: pillow in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (9.4.0)
# Requirement already satisfied: pyct in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (0.5.0)
# Requirement already satisfied: requests in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (2.31.0)
# Requirement already satisfied: scipy in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (1.10.1)
# Requirement already satisfied: toolz in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (0.12.0)
# Requirement already satisfied: xarray in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashader) (2023.6.0)
# Collecting fiona>=1.8.21 (from geopandas)
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/6e/40/b2830d90c80254dc6fefeb066bd4cbcd305a5058e79cf3fade5706184ea2/Fiona-1.9.4.post1-cp311-cp311-macosx_10_15_x86_64.whl.metadata
#   Downloading Fiona-1.9.4.post1-cp311-cp311-macosx_10_15_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.9 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (1.0.5)
# Requirement already satisfied: PyYAML>=3.10 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from bokeh>=1.0.0->hvplot) (6.3.2)
# Requirement already satisfied: matplotlib>=3.4 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from cartopy>=0.18.0->geoviews) (3.7.1)
# Requirement already satisfied: pyshp>=2.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Collecting click-plugins>=1.0 (from fiona>=1.8.21->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.21->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from holoviews>=1.11.0->hvplot) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from pandas->hvplot) (2022.7)
# Requirement already satisfied: markdown in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (4.65.0)
# Requirement already satisfied: bleach in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from panel>=0.11.0->hvplot) (4.7.1)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from dask->datashader) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from dask->datashader) (2023.3.0)
# Requirement already satisfied: partd>=1.2.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from dask->datashader) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from dask->datashader) (6.0.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from datashape->datashader) (0.6.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from numba->datashader) (0.40.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from requests->datashader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from requests->datashader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from requests->datashader) (1.26.16)
# Requirement already satisfied: zipp>=0.5 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask->datashader) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: locket in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from partd>=1.2.0->dask->datashader) (1.0.0)
# Requirement already satisfied: webencodings in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/mahasalmancheema/anaconda3/lib/python3.11/site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Downloading geopandas-0.14.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.7 MB/s eta 0:00:00a 0:00:01
# Downloading Fiona-1.9.4.post1-cp311-cp311-macosx_10_15_x86_64.whl (18.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.6/18.6 MB 29.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.14.0

# %%
import hvplot.pandas
import pandas as pd
import requests
from random import randrange
import geopandas as gpd
from shapely.geometry import Point
import geoviews as gv


from api_keys import geoapify_key

# %%
city_data_df = pd.read_csv("output_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167      3.70        94
# 1        1           waitangi -43.9535 -176.5597      9.34        79
# 2        2           bongaree -27.0797  153.1586     21.79        92
# 3        3     puerto natales -51.7236  -72.4875     13.25        47
# 4        4            klyuchi  52.2667   79.1667      6.28        51
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100       20.87      TF  2023-10-03 20:03:08
# 1          98        2.68      NZ  2023-10-03 20:03:08
# 2         100        1.85      AU  2023-10-03 20:00:09
# 3          40       12.35      CL  2023-10-03 20:03:09
# 4           1        2.64      RU  2023-10-03 20:03:09

# %%
city_data_df.shape[0]
# Out:
# 569

# %%
import holoviews as hv

# %%
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
hv.extension('bokeh')
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo= True,
    tiles = "OSM"
)

map_plot_1
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]
